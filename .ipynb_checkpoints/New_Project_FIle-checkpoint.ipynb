# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel(r'E:\notes\noorain_python\Python Class(19-Apr)\Project Data.xlsx')
data
# Out:
#               Segment                   Country           Product  \
# 0          Government                    Canada  Protective Cover
# 1          Government                   Germany  Protective Cover
# 2           Midmarket                    France  Protective Cover
# 3           Midmarket                   Germany  Protective Cover
# 4           Midmarket                    Mexico  Protective Cover
# ..                ...                       ...               ...
# 695    Small Business                    France        Smartphone
# 696    Small Business                    Mexico        Smartphone
# 697        Government                    Mexico              Case
# 698        Government                    Canada          Chargers
# 699  Channel Partners  United States of America            Tablet
#
#     Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# 0            None      1618.5                    3          20      32370.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month

# %%
data.drop(['Year','Month'], axis=1, inplace=True)

# %%
df = data.rename({'Month Number':'Month No.', 'Month Name':'Month', 2017:'Year' }, axis=1)

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month No.', 'Month', 'Year'],
#       dtype='object')

# %%
df1 = data[['Segment','Country','Product',' Sales','Month']].groupby(['Country','Month'])[' Sales'].sum()
df = df1.sort_values(ascending=False).nlargest(n=10)

# %%
plt.figure(figsize=(20,10))
df.plot(kind='bar')

# %%
data[data['Product'].isin(['Smartphone','Case', 'Charges'])]
# Out:
#               Segment  Country     Product Discount Band  Units Sold  \
# 6           Midmarket  Germany        Case          None       921.0
# 7    Channel Partners   Canada        Case          None      2518.0
# 8          Government   France        Case          None      1899.0
# 9    Channel Partners  Germany        Case          None      1545.0
# 10          Midmarket   Mexico        Case          None      2470.0
# ..                ...      ...         ...           ...         ...
# 665         Midmarket   Mexico  Smartphone          High      1870.0
# 669    Small Business   Mexico        Case          High       546.0
# 695    Small Business   France  Smartphone          High      2475.0
# 696    Small Business   Mexico  Smartphone          High       546.0
# 697        Government   Mexico        Case          High      1368.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# ...
