# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel(r'C:\Users\Shri_Ram\Downloads\2018-12 Production Totals.xlsx', sheet_name='Invoice Completes')
data.head()
# Out:
#       WorkItem TeamName        Specialist WorkItem Owner ID SR Creator Id  \
# 0  Angela Gibson's Team  Heather BeShears        E10467      Unidentified
# 1  Angela Gibson's Team  Heather BeShears        E10467      Unidentified
# 2  Angela Gibson's Team    Lakeisha Ivory        E01790      Unidentified
# 3  Angela Gibson's Team    Lakeisha Ivory        E01790      Unidentified
# 4  Angela Gibson's Team     Nancy Carbone        E10115      Unidentified
#
#    SR Creator Dsc WorkItem Complete Date-MMDDYYYY SR Received Date-MMDDYYYY  \
# 0             NaN                      2018-12-20                2018-12-13
# 1             NaN                      2018-12-20                2018-12-13
# 2             NaN                      2018-12-26                2018-12-17
# 3             NaN                      2018-12-26                2018-12-17
# 4             NaN                      2018-12-21                2018-12-18
#
#   SR Last Status Change Date-MMDDYYYY SR Status Code  \
# ...

# %%
data.tail()
# Out:
#                    WorkItem TeamName    Specialist WorkItem Owner ID  \
# 99432  Team listing for EXL LAS team    Sumit Negi        VE0225
# 99433  Team listing for EXL LAS team  Sunny Sharma        VE0048
# 99434  Team listing for EXL LAS team  Sunny Sharma        VE0048
# 99435  Team listing for EXL LAS team  Sunny Sharma        VE0048
# 99436  Team listing for EXL LAS team  Sunny Sharma        VE0048
#
#       SR Creator Id  SR Creator Dsc WorkItem Complete Date-MMDDYYYY  \
# 99432        VE0225             NaN                      2018-12-28
# 99433        E07822             NaN                      2018-12-26
# 99434        E07822             NaN                      2018-12-26
# 99435        E72750             NaN                      1950-01-01
# 99436        E72750             NaN                      1950-01-01
#
#       SR Received Date-MMDDYYYY SR Last Status Change Date-MMDDYYYY  \
# 99432                2018-12-27                          2018-12-28
# ...

# %%
data.columns
# Out:
# Index(['WorkItem TeamName', 'Specialist', 'WorkItem Owner ID', 'SR Creator Id',
#        'SR Creator Dsc', 'WorkItem Complete Date-MMDDYYYY',
#        'SR Received Date-MMDDYYYY', 'SR Last Status Change Date-MMDDYYYY',
#        'SR Status Code', 'Classification Description', 'SR Channel Id',
#        'TransCode', 'SR Priority Code', 'Work Item Seq', 'WFSR Id',
#        'Policy Number Id', 'Group Number', 'SR Invoice No',
#        'v SR Channel Business', 'Age'],
#       dtype='object')

# %%
df = data.groupby('Specialist')['SR Status Code'].agg('count')
df
# Out:
# Specialist
# Aakash Aakash           610
# Abhay Deyondi           596
# Abhilash Srivastava    1899
# Abhishek Dhaka         1083
# Amanpreet Kaur          795
#                        ...
# Vishva Tiwari           913
# Vishwas Chaurasia      1215
# Woo Lee                   3
# Yogesh Yadav            611
# Yolanda Jackson           6
# Name: SR Status Code, Length: 172, dtype: int64

# %%
plt.figure(figsize=(20,10))
df.plot(kind='bar')

# %%
data.describe(include='all').T
# Out:
#                                      count unique                     top  \
# WorkItem TeamName                    99419     15  Rangan Banerjee's Team
# Specialist                           99437    172             Harsh Verma
# WorkItem Owner ID                    99437    172              VE0256
# SR Creator Id                        98127   1175            Unidentified
# SR Creator Dsc                           0    NaN                     NaN
# WorkItem Complete Date-MMDDYYYY      99437     27     2018-12-18 00:00:00
# SR Received Date-MMDDYYYY            99437     65     2018-12-04 00:00:00
# SR Last Status Change Date-MMDDYYYY  99437     25     2018-12-18 00:00:00
# SR Status Code                       99437      3                      CR
# Classification Description           99437      3             Group Small
# SR Channel Id                        99437     13                      FX
# TransCode                            99437     74                      CC
# ...

# %%
data.columns
# Out:
# Index(['WorkItem TeamName', 'Specialist', 'WorkItem Owner ID', 'SR Creator Id',
#        'SR Creator Dsc', 'WorkItem Complete Date-MMDDYYYY',
#        'SR Received Date-MMDDYYYY', 'SR Last Status Change Date-MMDDYYYY',
#        'SR Status Code', 'Classification Description', 'SR Channel Id',
#        'TransCode', 'SR Priority Code', 'Work Item Seq', 'WFSR Id',
#        'Policy Number Id', 'Group Number', 'SR Invoice No',
#        'v SR Channel Business', 'Age'],
#       dtype='object')

# %%
data.head()
# Out:
#       WorkItem TeamName        Specialist WorkItem Owner ID SR Creator Id  \
# 0  Angela Gibson's Team  Heather BeShears        E10467      Unidentified
# 1  Angela Gibson's Team  Heather BeShears        E10467      Unidentified
# 2  Angela Gibson's Team    Lakeisha Ivory        E01790      Unidentified
# 3  Angela Gibson's Team    Lakeisha Ivory        E01790      Unidentified
# 4  Angela Gibson's Team     Nancy Carbone        E10115      Unidentified
#
#    SR Creator Dsc WorkItem Complete Date-MMDDYYYY SR Received Date-MMDDYYYY  \
# 0             NaN                      2018-12-20                2018-12-13
# 1             NaN                      2018-12-20                2018-12-13
# 2             NaN                      2018-12-26                2018-12-17
# 3             NaN                      2018-12-26                2018-12-17
# 4             NaN                      2018-12-21                2018-12-18
#
#   SR Last Status Change Date-MMDDYYYY SR Status Code  \
# ...

# %%
df = data.groupby('TransCode')['TransCode'].agg('count')
df
# Out:
# TransCode
# 11     89
# 1A    227
# 1B     46
# 1C      1
# 1D      1
#      ...
# UM    308
# VV      1
# WP      3
# XX     47
# Z1      3
# Name: TransCode, Length: 74, dtype: int64

# %%
data['Age'].unique()
# Out:
# array([  0,   1,   2,  13,   4,   8,   3,   5,   7,   6,  20,  25,  11,
#         10,  15,  14,   9,  32,  42,  16,  27,  18,  12,  19,  43,  28,
#         21,  47,  33,  17,  54,  34,  22,  23,  26,  29,  31,  36,  38,
#         39,  46,  35,  24,  51,  30,  45,  37,  44,  48,  40,  41,  -7,
#        -36, -23,  56, -29, -34, -41, -40, -45], dtype=int64)

# %%
data['Age'][data['Age']>5].agg('count')
# Out:
# 4137

# %%
data['Age'].agg('count')
# Out:
# 99437

# %%
SLA = 100 - data['Age'][data['Age']>5].agg('count')/data['Age'].agg('count')*100
SLA
# Out:
# 95.83957681748242

# %%
SLA = 100 - data['Age'][data['Age']>9].agg('count')/data['Age'].agg('count')*100
SLA
# Out:
# 98.91690215915605

# %%
data['Specialist'].unique()
# Out:
# array(['Heather BeShears', 'Lakeisha Ivory', 'Nancy Carbone', 'Woo Lee',
#        'Yolanda Jackson', 'Brys Shumate', 'Julie Laudin', 'Kimberly Lund',
#        'Calandra Walker', 'Christopher Reeves', 'Jeanette Sykes',
#        'Kasheena Willis', 'Lakesha Meadows', 'Shedrick Adams',
#        'Tamesia Paschal', 'Tanesha Wilbert', 'Angela Viger',
#        'Debby Bowen', 'Jeromy Serrano', 'Ladonna Turner',
#        'Miranda Martinez', 'Tekey Williams', 'Valerie Workman',
#        'Sandeep Sen', 'Amanpreet Kaur', 'Anant Verma', 'Anuj Dhiman',
#        'Deepak Rawat', 'Gagan Gupta', 'Harsh Verma', 'Meribemo Kikon',
#        'Monika Anand', 'Neha Singh', 'Nidhi Sharma', 'Nitin Som',
#        'Prabendra Singh', 'Pushpa Kumari', 'Rahul Kumar', 'Rajat Manhas',
#        'Rashmi Bisht', 'Rohan Kunwar', 'Shahnawaz Hasan', 'Vikash Tomar',
#        'Vishva Tiwari', 'Vishwas Chaurasia', 'Ambroz Ali', 'Amit Negi',
#        'Amit Rajpoot', 'Ashish Bajaj', 'Bhupesh Bhupesh', 'Farukh Khan',
# ...

# %%
df1 = data[data['Specialist']=='Sanskriti Awasthi']

# %%
df1['Age'][df1['Age']>5].agg('count')
# Out:
# 125

# %%
SLA = 100 - df1['Age'][df1['Age']>5].agg('count')/df1['Age'].agg('count')*100
SLA
# Out:
# 92.85305889079474

# %%
df1['Age'][df1['Age']>9].agg('count')
# Out:
# 72

# %%
STA = 100 - df1['Age'][df1['Age']>9].agg('count')/df1['Age'].agg('count')*100
STA
# Out:
# 95.88336192109777

# %%
data.columns
# Out:
# Index(['WorkItem TeamName', 'Specialist', 'WorkItem Owner ID', 'SR Creator Id',
#        'SR Creator Dsc', 'WorkItem Complete Date-MMDDYYYY',
#        'SR Received Date-MMDDYYYY', 'SR Last Status Change Date-MMDDYYYY',
#        'SR Status Code', 'Classification Description', 'SR Channel Id',
#        'TransCode', 'SR Priority Code', 'Work Item Seq', 'WFSR Id',
#        'Policy Number Id', 'Group Number', 'SR Invoice No',
#        'v SR Channel Business', 'Age'],
#       dtype='object')

# %%
df2 = data[(data['Specialist']=='Sumit Negi') & (data['TransCode'])][data['Age']>9]
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                    WorkItem TeamName  Specialist WorkItem Owner ID  \
# 98874  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98875  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98876  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98886  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99132  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99180  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99324  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99337  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99338  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99353  Team listing for EXL LAS team  Sumit Negi        VE0225
#
#       SR Creator Id  SR Creator Dsc WorkItem Complete Date-MMDDYYYY  \
# ...

# %%
df3 = data[(data['Specialist']=='Sumit Negi') & (data['TransCode'])][data['Age']>5]
df3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                    WorkItem TeamName  Specialist WorkItem Owner ID  \
# 98829  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98832  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98833  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98865  Team listing for EXL LAS team  Sumit Negi        VE0225
# 98866  Team listing for EXL LAS team  Sumit Negi        VE0225
# ...                              ...         ...               ...
# 99338  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99353  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99368  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99369  Team listing for EXL LAS team  Sumit Negi        VE0225
# 99370  Team listing for EXL LAS team  Sumit Negi        VE0225
#
# ...

# %%
df3 = data[(data['WorkItem TeamName']=='Team listing for EXL LAS team') & (data['TransCode'])][data['Age']>5].agg('count')
df3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# WorkItem TeamName                      863
# Specialist                             863
# WorkItem Owner ID                      863
# SR Creator Id                          863
# SR Creator Dsc                           0
# WorkItem Complete Date-MMDDYYYY        863
# SR Received Date-MMDDYYYY              863
# SR Last Status Change Date-MMDDYYYY    863
# SR Status Code                         863
# Classification Description             863
# SR Channel Id                          863
# TransCode                              863
# SR Priority Code                       863
# Work Item Seq                          863
# WFSR Id                                863
# Policy Number Id                       863
# Group Number                           863
# ...

# %%
df4 = data[(data['WorkItem TeamName']=='Team listing for EXL LAS team') & (data['TransCode'])][data['Age']>9].agg('count')
df4
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# WorkItem TeamName                      161
# Specialist                             161
# WorkItem Owner ID                      161
# SR Creator Id                          161
# SR Creator Dsc                           0
# WorkItem Complete Date-MMDDYYYY        161
# SR Received Date-MMDDYYYY              161
# SR Last Status Change Date-MMDDYYYY    161
# SR Status Code                         161
# Classification Description             161
# SR Channel Id                          161
# TransCode                              161
# SR Priority Code                       161
# Work Item Seq                          161
# WFSR Id                                161
# Policy Number Id                       161
# Group Number                           161
# ...

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1612102841582' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Af&#47;AflacInvoiceWorkDashboard&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AflacInvoiceWorkDashboard&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Af&#47;AflacInvoiceWorkDashboard&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1612102841582');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1366px';vizElement.style.height='795px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1366px';vizElement.style.height='795px';} else { vizElement.style.width='100%';vizElement.style.height='1527px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1612102841582' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Af&#47;AflacInvoiceWorkDashboard&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AflacInvoiceWorkDashboard&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Af&#47;AflacInvoiceWorkDashboard&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='
# ...
