# %%
# !pip install pycaret

# %%
from pycaret.datasets import  get_data

# %%
diabetes_df = get_data('diabetes')
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %%
diabetes_df['Class variable'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Class variable, dtype: int64

# %%
from pycaret.classification import *
clf = setup(data=diabetes_df, target='Class variable')
# Out:
#                                Description             Value
# 0                               session_id              1869
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 23)
# 12                    Transformed Test Set         (231, 23)
# 13                      Shuffle Train-Test              True
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# gbc          Gradient Boosting Classifier    0.7858  0.8207  0.6257  0.7320
# lr                    Logistic Regression    0.7857  0.8447  0.6047  0.7404
# ridge                    Ridge Classifier    0.7821  0.0000  0.5781  0.7455
# lda          Linear Discriminant Analysis    0.7766  0.8393  0.5781  0.7317
# rf               Random Forest Classifier    0.7747  0.8249  0.5719  0.7355
# et                 Extra Trees Classifier    0.7747  0.8074  0.5617  0.7303
# lightgbm  Light Gradient Boosting Machine    0.7673  0.8122  0.6152  0.6897
# knn                K Neighbors Classifier    0.7560  0.7740  0.5459  0.6958
# ada                  Ada Boost Classifier    0.7375  0.7806  0.5509  0.6489
# dt               Decision Tree Classifier    0.7262  0.6879  0.5664  0.6132
# nb                            Naive Bayes    0.7020  0.7665  0.3023  0.6600
# ...

# %% [markdown]
# **Regression Problem**

# %%
boston_df = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
from pycaret.regression import *

# %%
reg = setup(data=boston_df, target='medv')
# Out:
#                                Description             Value
# 0                               session_id               884
# 1                                   Target              medv
# 2                            Original Data         (506, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                11
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (354, 21)
# 10                    Transformed Test Set         (152, 21)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.1928  12.2624  3.3665  0.8425
# lightgbm  Light Gradient Boosting Machine  2.2913  11.8252  3.3162  0.8425
# rf                Random Forest Regressor  2.3068  13.4775  3.5193  0.8170
# gbr           Gradient Boosting Regressor  2.3618  13.8446  3.5836  0.8156
# ada                    AdaBoost Regressor  2.8802  17.7757  4.0616  0.7716
# lr                      Linear Regression  3.2756  22.4955  4.6376  0.7096
# ridge                    Ridge Regression  3.2649  22.6819  4.6498  0.7087
# br                         Bayesian Ridge  3.2914  22.9687  4.6628  0.7075
# en                            Elastic Net  3.6658  27.3205  5.0958  0.6503
# lasso                    Lasso Regression  3.6851  27.7658  5.1331  0.6459
# dt                Decision Tree Regressor  3.4228  26.2419  5.0503  0.6206
# ...

# %%
reg_model = create_model('et')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.3928  19.0302  4.3624  0.7637  0.1697  0.1286
# 1     2.5573  12.0790  3.4755  0.8966  0.1685  0.1322
# 2     2.7258  21.9605  4.6862  0.7712  0.1815  0.1452
# 3     1.6334   4.2689  2.0661  0.9423  0.0956  0.0763
# 4     1.8407   5.6677  2.3807  0.8955  0.1258  0.1028
# 5     1.8786   6.3074  2.5114  0.9132  0.1177  0.0866
# 6     1.9473   7.4258  2.7250  0.7828  0.1363  0.1070
# 7     2.1938  11.2901  3.3601  0.8321  0.1442  0.1035
# 8     2.6642  25.0071  5.0007  0.7749  0.1915  0.1276
# 9     2.0944   9.5876  3.0964  0.8530  0.1022  0.0839
# Mean  2.1928  12.2624  3.3665  0.8425  0.1433  0.1094
# SD    0.3584   6.9040  0.9641  0.0635  0.0318  0.0220

# %%
reg_model
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=884, verbose=0, warm_start=False)

# %%
reg_model.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 884,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Hyper Tuning of model

# %%
#reg_model_hypertune = tune_model('et', n_iter=50, optimize='mae')

# %% [markdown]
# Clustering

# %%
jewellery = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
from pycaret.clustering import  *
clust_algo = setup(jewellery)
# Out:
#                                Description                 Value
# 0                               session_id                  4522
# 1                            Original Data              (505, 4)
# 2                           Missing Values                 False
# 3                         Numeric Features                     4
# 4                     Categorical Features                     0
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data              (505, 4)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  cluster-default-name
# ...

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.7207          5011.8113  ...           0             0
#
# [1 rows x 6 columns]

# %%
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=-1, precompute_distances='deprecated',
#        random_state=4522, tol=0.0001, verbose=0)

# %%
#Assign the labels to dataframe
kmeans_df = assign_model(kmeans)

# %%
kmeans_df
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.829923  Cluster 0
# 1     59   81799       0.791082   5417.661426  Cluster 0
# 2     62   74751       0.702657   9258.992965  Cluster 0
# 3     59   74373       0.765680   7346.334504  Cluster 0
# 4     87   17760       0.348778  16869.507130  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775389  Cluster 3
# 501   93   19934       0.203140  17969.693769  Cluster 1
# 502   90   35297       0.355149  16091.401954  Cluster 1
# 503   91   20681       0.354679  18401.088445  Cluster 1
# 504   89   30267       0.289310  14386.351880  Cluster 1
#
# [505 rows x 5 columns]

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d5b6abf0-e597-47ce-ae8e-4dd72d7d5276" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d5b6abf0-e597-47ce-ae8e-4dd72d7d5276")) {
#                     Plotly.newPlot(
#                         'd5b6abf0-e597-47ce-ae8e-4dd72d7d5276',
# ...

# %%
ap = create_model('ap')
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0           0                  0  ...           0             0
#
# [1 rows x 6 columns]

# %%
ap
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#                     damping=0.5, max_iter=200, preference=None,
#                     random_state='warn', verbose=False)

# %%
ap_df = assign_model(ap)

# %%
ap_df
# Out:
#      Age  Income  SpendingScore       Savings     Cluster
# 0     58   77769       0.791329   6559.829923  Cluster -1
# 1     59   81799       0.791082   5417.661426  Cluster -1
# 2     62   74751       0.702657   9258.992965  Cluster -1
# 3     59   74373       0.765680   7346.334504  Cluster -1
# 4     87   17760       0.348778  16869.507130  Cluster -1
# ..   ...     ...            ...           ...         ...
# 500   28  101206       0.387441  14936.775389  Cluster -1
# 501   93   19934       0.203140  17969.693769  Cluster -1
# 502   90   35297       0.355149  16091.401954  Cluster -1
# 503   91   20681       0.354679  18401.088445  Cluster -1
# 504   89   30267       0.289310  14386.351880  Cluster -1
#
# [505 rows x 5 columns]

# %%
heir = create_model('hclust')
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0       0.706           4827.224  ...           0             0
#
# [1 rows x 6 columns]

# %%
heir
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=4)

# %%
heir_df = assign_model(heir)

# %%
heir_df
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.829923  Cluster 2
# 1     59   81799       0.791082   5417.661426  Cluster 2
# 2     62   74751       0.702657   9258.992965  Cluster 2
# 3     59   74373       0.765680   7346.334504  Cluster 2
# 4     87   17760       0.348778  16869.507130  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775389  Cluster 3
# 501   93   19934       0.203140  17969.693769  Cluster 1
# 502   90   35297       0.355149  16091.401954  Cluster 1
# 503   91   20681       0.354679  18401.088445  Cluster 1
# 504   89   30267       0.289310  14386.351880  Cluster 1
#
# [505 rows x 5 columns]

# %%
plot_model(heir)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="742755cb-390a-4d73-885c-69f2a1357744" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("742755cb-390a-4d73-885c-69f2a1357744")) {
#                     Plotly.newPlot(
#                         '742755cb-390a-4d73-885c-69f2a1357744',
# ...

# %%
#Data Preprocessing
#Train Test Split
insurance = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
setup(data=insurance, target='charges', train_size=0.5)
# Out:
#                                Description             Value
# 0                               session_id              2240
# 1                                   Target           charges
# 2                            Original Data         (1338, 7)
# 3                           Missing Values             False
# 4                         Numeric Features                 2
# 5                     Categorical Features                 4
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (669, 14)
# 10                    Transformed Test Set         (669, 14)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...
