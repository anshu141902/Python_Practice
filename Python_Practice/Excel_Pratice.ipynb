# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel(r'E:\notes\noorain_python\Python Class(19-Apr)\Project Data.xlsx')
df.head()
# Out:
#       Segment  Country           Product Discount Band  Units Sold  \
# 0  Government   Canada  Protective Cover          None      1618.5
# 1  Government  Germany  Protective Cover          None      1321.0
# 2   Midmarket   France  Protective Cover          None      2178.0
# 3   Midmarket  Germany  Protective Cover          None       888.0
# 4   Midmarket   Mexico  Protective Cover          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  2017
# ...

# %%
output = pd.crosstab(df['Country'], df['Product'],values=df[' Sales'], aggfunc=[np.sum])
output
# Out:
#                                        sum                          \
# Product                  Bluetooth Speaker        Case    Chargers
# Country
# Canada                         3329490.340  2711919.03  7611520.99
# France                         3978096.235  3527382.37  5597751.06
# Germany                        4392907.000  3566044.37  5229814.74
# Mexico                         2250737.890  1941329.31  7627731.39
# United States of America       4298828.000  3644126.80  6944325.77
#
#
# Product                  Protective Cover   Smartphone      Tablet
# Country
# Canada                        2610204.340  3855765.875  4768754.31
# France                        3423321.895  4016427.130  3811193.59
# Germany                       3062340.680  3960250.260  3293983.77
# Mexico                        2879601.420  3077555.390  3172396.71
# United States of America      1839839.550  2837117.405  5465592.64

# %%
data = pd.read_excel(r'E:\notes\noorain_python\Python Class(10-May)\Data\Evening.xlsx')
data
# Out:
#   CODE                    EmpName    Shift  Salary
# 0  KBD  NAIYER IQUBAL              Evening   35536
# 1  NWH  SUSANTA SAHOO              Evening   10090
# 2  ZFS  SRIKANTA SAMAL             Evening   28272
# 3  QBL  BHAGAT SINGH DHANKA        Evening   12788
# 4  XOI  VIJAY KUMAR                Evening   11196
# 5  NXE  GIRIRAJ DUTTA              Evening   30509

# %%
df = pd.DataFrame()
xl = pd.ExcelFile(r'E:\notes\noorain_python\Python Class(10-May)\Data\Evening.xlsx')
for i in xl.sheet_names:
    sh = xl.parse(i)
    df = df.append(sh)
print(df)
# Out:
#   CODE                    EmpName     Shift  Salary
# 0  KBD  NAIYER IQUBAL               Evening   35536
# 1  NWH  SUSANTA SAHOO               Evening   10090
# 2  ZFS  SRIKANTA SAMAL              Evening   28272
# 3  QBL  BHAGAT SINGH DHANKA         Evening   12788
# 4  XOI  VIJAY KUMAR                 Evening   11196
# 5  NXE  GIRIRAJ DUTTA               Evening   30509
# 0  KBD  NAIYER IQUBAL               General   35536
# 1  NWH  SUSANTA SAHOO               General   10090
# 2  ZFS  SRIKANTA SAMAL              General   28272
# 3  QBL  BHAGAT SINGH DHANKA         General   12788
# 4  XOI  VIJAY KUMAR                 General   11196
# 5  NXE  GIRIRAJ DUTTA               General   30509
# 0  KBD  NAIYER IQUBAL                 Night   35536
# 1  NWH  SUSANTA SAHOO                 Night   10090
# 2  ZFS  SRIKANTA SAMAL                Night   28272
# 3  QBL  BHAGAT SINGH DHANKA           Night   12788
# 4  XOI  VIJAY KUMAR                   Night   11196
# ...

# %%
import glob

# %%
data = glob.glob('E://notes//noorain_python//Python Class(10-May)//Data//*.xlsx')

# %%
for i in data:
    print(i)
# Out:
# E://notes//noorain_python//Python Class(10-May)//Data\Evening.xlsx
# E://notes//noorain_python//Python Class(10-May)//Data\General.xlsx
# E://notes//noorain_python//Python Class(10-May)//Data\Morning.xlsx
# E://notes//noorain_python//Python Class(10-May)//Data\Night.xlsx

# %%
df = pd.DataFrame()
data = glob.glob('E://notes//noorain_python//Python Class(10-May)//Data1//*.xlsx')
for i in data:
    xl = pd.read_excel(i)
    df = df.append(xl)
print(df)
# Out:
#                      Customer   Region  Invoice       Date  Years Product  \
# 0     Alluring Bottle Company  Central    19022 2015-11-12   2015    U624
# 1     Alluring Bottle Company  Central    19026 2016-08-24   2016    Q197
# 2     Alluring Bottle Company  Central    19038 2017-09-10   2017    W164
# 3     Alluring Bottle Company  Central    19047 2015-04-16   2015    D506
# 4     Alluring Bottle Company  Central    19088 2013-07-05   2013    D506
# ...                       ...      ...      ...        ...    ...     ...
# 5535  Wonderful Meter Company     East   149835 2014-01-29   2014    W164
# 5536  Wonderful Meter Company     East   149917 2017-09-05   2017    D506
# 5537  Wonderful Meter Company     East   149935 2014-08-22   2014    W164
# 5538  Wonderful Meter Company     East   150035 2017-11-04   2017    U624
# 5539  Wonderful Meter Company     East   150052 2016-09-21   2016    D506
#
#        Revenue   Profit
# 0     12848.56  3212.14
# 1     12968.28  3760.74
# ...

# %%
df['Customer'].unique()
# Out:
# array(['Alluring Bottle Company', 'Effortless Thermostat Company',
#        'Excellent Toothpick Company', 'Exclusive Shingle Supply',
#        'Fabulous Luggage Traders', 'Fabulous Quilt Company',
#        'Fabulous Tripod Corporation', 'Functional Washer Inc.',
#        'Honest Belt Corporation', 'Magnificent Bobsled Inc.',
#        'Mouthwatering Eggbeater Company', 'New Calculator Traders',
#        'Paramount Faucet Inc.', 'Rare Meter Company',
#        'Rare Washer Corporation', 'Special Marble Corporation',
#        'Steadfast Door Partners', 'Superior Aquarium Corporation',
#        'Sure Shovel Inc.', 'Tremendous Aerobic Inc.',
#        'Trouble-Free Door Supply', 'Trustworthy Briefcase Inc.',
#        'Well-Suited Thermostat Inc.', 'Wonderful Meter Company'],
#       dtype=object)

# %%
df.tail()
# Out:
#                      Customer Region  Invoice       Date  Years Product  \
# 5535  Wonderful Meter Company   East   149835 2014-01-29   2014    W164
# 5536  Wonderful Meter Company   East   149917 2017-09-05   2017    D506
# 5537  Wonderful Meter Company   East   149935 2014-08-22   2014    W164
# 5538  Wonderful Meter Company   East   150035 2017-11-04   2017    U624
# 5539  Wonderful Meter Company   East   150052 2016-09-21   2016    D506
#
#        Revenue   Profit
# 5535  13224.96  4099.20
# 5536   9537.60  1812.00
# 5537  19538.40  6056.96
# 5538  23533.58  5883.93
# 5539  20302.40  3857.60

# %%
df = pd.DataFrame()
data = glob.glob('E://notes//noorain_python//Python Class(10-May)//Data2//*.xlsx')
for i in data:
    xl = pd.read_excel(i)
    df = df.append(xl)

# %%
df
# Out:
#              Agent  AcctType   OpenedBy        Branch Customer       Date  \
# 0   Abhishek Kumar        CD     Teller       Central      New 2015-08-21
# 1      Varun Kumar        CD  New Accts       Central      New 2019-09-02
# 2      Ashok Kumar        CD     Teller       Central      New 2016-02-23
# 3      Rahul Kumar        CD  New Accts  North County      New 2019-08-15
# 4      Ashok Kumar        CD  New Accts  North County      New 2017-04-26
# ..             ...       ...        ...           ...      ...        ...
# 94  Abhishek Kumar  Checking  New Accts      Westside      New 2017-02-25
# 95  Abhishek Kumar  Checking  New Accts      Westside      New 2019-09-04
# 96  Abhishek Kumar  Checking  New Accts      Westside      New 2017-08-30
# 97  Abhishek Kumar  Checking  New Accts      Westside      New 2015-03-11
# 98  Abhishek Kumar  Checking  New Accts      Westside      New 2015-06-29
#
#     Amount
# 0    14571
# 1    16000
# 2    11779
# 3     7028
# 4    14067
# ...

# %%
df.head()
# Out:
#       Segment  Country           Product Discount Band  Units Sold  \
# 0  Government   Canada  Protective Cover          None      1618.5
# 1  Government  Germany  Protective Cover          None      1321.0
# 2   Midmarket   France  Protective Cover          None      2178.0
# 3   Midmarket  Germany  Protective Cover          None       888.0
# 4   Midmarket   Mexico  Protective Cover          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  2017
# ...

# %%
data = pd.crosstab(index=[df['Segment'], df['Country']], columns=df['Product'], values=df[' Sales'], aggfunc=([np.sum,np.min,np.max,np.count_nonzero]))

# %%
data
# Out:
#                                                         sum              \
# Product                                   Bluetooth Speaker        Case
# Segment          Country
# Channel Partners Canada                           34315.320    55561.32
#                  France                           33886.440    48264.36
#                  Germany                          60088.680    45238.80
#                  Mexico                           28434.000    68634.72
#                  United States of America         26199.600    44145.36
# Enterprise       Canada                          792843.750   376312.50
#                  France                          379543.750   367282.50
#                  Germany                         437547.500   497477.50
#                  Mexico                          672087.500   339910.00
#                  United States of America       1299215.000  1033861.25
# Government       Canada                         1374572.470   829859.91
# ...
