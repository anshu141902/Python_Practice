# %% [raw]
# # Description of Columns
#
# columns                                  escription
# case_id                                  Case_ID registered in Hospital
# Hospital_code                            Unique code for the Hospital
# Hospital_type_code	                     Unique code for the type of Hospital
# City_Code_Hospital	                     City Code of the Hospital
# Hospital_region_code	                 Region Code of the Hospital
# Available Extra Rooms in Hospital	     Number of Extra rooms available in the Hospital
# Department	                             Department overlooking the case
# Ward_Type	                             Code for the Ward type
# Ward_Facility_Code	                     Code for the Ward Facility
# Bed Grade	                             Condition of Bed in the Ward
# patientid	                             Unique Patient Id
# City_Code_Patient	                     City Code for the patient
# Type of Admission	                     Admission Type registered by the Hospital
# Severity of Illness	                     Severity of the illness recorded at the time of admission
# Visitors with Patient	                 Number of Visitors with the patient
# Age	                                     Age of the patient
# Admission_Deposit	                     Deposit at the Admission Time
# Stay	                                 Stay Days by the patient

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Shri_Ram\Downloads\healthcare\train_data.csv')
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
def convert_age_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_age_to_num('5625')
# Out:
# 5625.0

# %%
convert_age_to_num('51-60')
# Out:
# 55.5

# %%
convert_age_to_num('41-50')
# Out:
# 45.5

# %%
df['Stay'].unique()
# Out:
# array(['0-10', '41-50', '31-40', '11-20', '51-60', '21-30', '71-80',
#        'More than 100 Days', '81-90', '61-70', '91-100'], dtype=object)

# %%
df[df['Stay'].isin(['More than 100 Days'])].count()
# Out:
# case_id                              6683
# Hospital_code                        6683
# Hospital_type_code                   6683
# City_Code_Hospital                   6683
# Hospital_region_code                 6683
# Available Extra Rooms in Hospital    6683
# Department                           6683
# Ward_Type                            6683
# Ward_Facility_Code                   6683
# Bed Grade                            6681
# patientid                            6683
# City_Code_Patient                    6550
# Type of Admission                    6683
# Severity of Illness                  6683
# Visitors with Patient                6683
# Age                                  6683
# Admission_Deposit                    6683
# Stay                                 6683
# dtype: int64

# %%
df.describe().T
# Out:
#                                       count           mean           std  \
# case_id                            318438.0  159219.500000  91925.276847
# Hospital_code                      318438.0      18.318841      8.633755
# City_Code_Hospital                 318438.0       4.771717      3.102535
# Available Extra Rooms in Hospital  318438.0       3.197627      1.168171
# Bed Grade                          318325.0       2.625807      0.873146
# patientid                          318438.0   65747.579472  37979.936440
# City_Code_Patient                  313906.0       7.251859      4.745266
# Visitors with Patient              318438.0       3.284099      1.764061
# Admission_Deposit                  318438.0    4880.749392   1086.776254
#
#                                       min       25%       50%        75%  \
# case_id                               1.0  79610.25  159219.5  238828.75
# Hospital_code                         1.0     11.00      19.0      26.00
# ...

# %%
df_prepare = df.copy()
df_prepare['avg_age'] = df_prepare['Age'].apply(convert_age_to_num)
df_prepare['avg_stay'] = df_prepare['Stay'].apply(convert_age_to_num)

# %%
df_prepare = df_prepare.copy().drop(['Age', 'Stay'], axis=1)

# %%
df_prepare.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
df_prepare.corr().T
# Out:
#                                     case_id  Hospital_code  \
# case_id                            1.000000      -0.043023
# Hospital_code                     -0.043023       1.000000
# City_Code_Hospital                -0.011352       0.128294
# Available Extra Rooms in Hospital  0.042580      -0.059638
# Bed Grade                          0.013702      -0.013739
# patientid                         -0.004150       0.002291
# City_Code_Patient                  0.065196      -0.015530
# Visitors with Patient              0.001309      -0.028500
# Admission_Deposit                 -0.045972       0.045446
# avg_age                           -0.114852       0.016332
# avg_stay                          -0.060092       0.040198
#
#                                    City_Code_Hospital  \
# case_id                                     -0.011352
# Hospital_code                                0.128294
# City_Code_Hospital                           1.000000
# ...

# %%
len(df[df_prepare['avg_stay'].isin(['More than 100 Days'])])
# Out:
# 0

# %%
df_prepare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
df_prepare['avg_stay'] = df_prepare['avg_stay'].fillna(100)

# %%
df_prepare.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Admission_Deposit',
#        'avg_age', 'avg_stay'],
#       dtype='object')

# %%
sns.pairplot(df_prepare)

# %%
print(df_prepare['case_id'].unique())
print('**************************************************************')
print(df_prepare['Hospital_code'].unique())
print('**************************************************************')
print(df_prepare['Hospital_type_code'].unique())
print('**************************************************************')
print(df_prepare['City_Code_Hospital'].unique())
print('**************************************************************')
print(df_prepare['Hospital_region_code'].unique())
print('**************************************************************')
print(df_prepare['Available Extra Rooms in Hospital'].unique())
print('**************************************************************')
print(df_prepare['Ward_Type'].unique())
print('**************************************************************')
print(df_prepare['Ward_Facility_Code'].unique())
print('**************************************************************')
print(df_prepare['Bed Grade'].unique())
print('**************************************************************')
print(df_prepare['patientid'].unique())
print('**************************************************************')
print(df_prepare['City_Code_Patient'].unique())
print('**************************************************************')
print(df_prepare['Type of Admission'].unique())
print('**************************************************************')
print(df_prepare['Severity of Illness'].unique())
print('**************************************************************')
print(df_prepare['Visitors with Patient'].unique())
print('**************************************************************')
print(df_prepare['Admission_Deposit'].unique())
print('**************************************************************')
print(df_prepare['avg_age'].unique())
print('**************************************************************')
print(df_prepare['avg_stay'].unique())
print('**************************************************************')
# Out:
# [     1      2      3 ... 318436 318437 318438]
# **************************************************************
# [ 8  2 10 26 23 32  1 22 16  9  6 29 12  3 21 28 27 19  5 14 13 31 24 17
#  25 15 11 30 18  4  7 20]
# **************************************************************
# ['c' 'e' 'b' 'a' 'f' 'd' 'g']
# **************************************************************
# [ 3  5  1  2  6  9 10  4 11  7 13]
# **************************************************************
# ['Z' 'X' 'Y']
# **************************************************************
# [ 3  2  1  4  6  5  7  8  9 10 12  0 11 20 14 21 13 24]
# **************************************************************
# ['R' 'S' 'Q' 'P' 'T' 'U']
# **************************************************************
# ['F' 'E' 'D' 'B' 'A' 'C']
# **************************************************************
# [ 2.  3.  4.  1. nan]
# **************************************************************
# ...

# %%
df_prepare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
df_prepare.quantile(0.95)
# Out:
# case_id                              302516.15
# Hospital_code                            30.00
# City_Code_Hospital                       11.00
# Available Extra Rooms in Hospital         5.00
# Bed Grade                                 4.00
# patientid                            125106.00
# City_Code_Patient                        16.00
# Visitors with Patient                     6.00
# Admission_Deposit                      6926.00
# avg_age                                  75.50
# avg_stay                                 75.50
# Name: 0.95, dtype: float64

# %%
sns.heatmap(df_prepare.isna(), annot=True, fmt="d")
