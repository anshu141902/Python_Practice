# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time

# %%
# Path to the page url and webdriver
page_url = 'https://www.naukri.com/step-up-list-of-companies-hiring-during-coronavirus-covid-19'
path_to_webdriver = "E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe"
# Start the web session by passing the path and the page url
driver = webdriver.Chrome(path_to_webdriver)
driver.get(page_url)

# %%
driver.maximize_window() 
driver.implicitly_wait(20)

# %%
html=BeautifulSoup(driver.page_source, 'lxml')

# %%
html.prettify()
# Out:
# '<html lang="en" xmlns="http://www.w3.org/1999/xhtml">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <base href="//www.naukri.com"/>\n  <meta content="notranslate" name="google"/>\n  <link href="https://static.naukimg.com" rel="dns-prefetch preconnect"/>\n  <link href="https://img.naukimg.com" rel="dns-prefetch preconnect"/>\n  <link href="https://logs.naukri.com" rel="dns-prefetch preconnect"/>\n  <link href="https://lg.naukri.com" rel="dns-prefetch preconnect"/>\n  <link href="https://www.google-analytics.com" rel="dns-prefetch preconnect"/>\n  <link href="https://www.googleadservices.com" rel="dns-prefetch preconnect"/>\n  <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch preconnect"/>\n  <link href="https://www.googletagmanager.com" rel="dns-prefetch preconnect"/>\n  <link as="style" h
# ...

# %%
company_name = html.find('h2', class_='company-name').get_text()
print(company_name)
# Out:
# Tech Mahindra

# %%
entries = html.find_all('h2', {'class':'company-name'})
company_Name = [e.get_text() for e in entries]
company_Name
# Out:
# ['Tech Mahindra',
#  'MSN Laboratories',
#  'Tata Elxsi',
#  'DS Group',
#  'Wesley Clover',
#  'Muthoot Fincorp',
#  'Tata Steel',
#  'Veritas',
#  'Newt Global',
#  'Maintec',
#  'IDBI Life Insurance',
#  'Canara HSBC OBC Life Insurance',
#  'Amazon',
#  'Prime Focus',
#  'Tata Steel',
#  'Dell',
#  'HDFC Bank',
#  'HSBC EDP',
#  'O&G Skills',
#  'Atria',
#  'Meyer Organics',
#  'Zydex',
#  'Directi',
#  'Hurix Systems',
#  'Aegis',
#  'UFO Moviez',
#  'Birlasoft',
#  'Impetus',
#  'Amity University',
#  "Moody's Analytics",
#  'Flipkart',
#  'Murugappa',
#  'ANSYS Software',
#  'Cipla',
#  'Info Edge',
#  'Sutherland',
#  'Religare Health Insurance',
#  'Bajaj Electricals',
#  'Dr Lal Pathlabs',
#  'BMC Software',
#  'Frankfinn',
#  'Applied Materials',
#  'Kotak Mahindra',
#  'DHFL Life Insurance',
#  'Tech Mahindra',
#  'Prokarma',
#  'Entrust Global',
#  'Data Intensity',
#  'Sterlite',
#  'Zensar',
#  'Torrent Pharma',
#  'Optum Global',
#  'Cadila',
# ...

# %%
company_card = html.find('div', class_='company-card').get_text()
print(company_card.split(" ")[0]
# Out:
# MNCTech

# %%
company_card = html.find('div', class_='company-card').get_text()
print(company_card.split(" ")[1])
# Out:
# Mahindra67

# %%
company_card = html.find('div', class_='company-card').get_text()
print(company_card.split(" ")[2])
# Out:
# Openings

# %%
company_card = html.find('div', class_='company-card').get_text()
company_card
# Out:
# 'MNCTech Mahindra67 Openings'

# %%
entries = html.find_all('h2', {'class':'company-name'})
company_Name = [e.get_text() for e in entries]
company_Name
# Out:
# ['Tech Mahindra',
#  'MSN Laboratories',
#  'Tata Elxsi',
#  'DS Group',
#  'Wesley Clover',
#  'Muthoot Fincorp',
#  'Tata Steel',
#  'Veritas',
#  'Newt Global',
#  'Maintec',
#  'IDBI Life Insurance',
#  'Canara HSBC OBC Life Insurance',
#  'Amazon',
#  'Prime Focus',
#  'Tata Steel',
#  'Dell',
#  'HDFC Bank',
#  'HSBC EDP',
#  'O&G Skills',
#  'Atria',
#  'Meyer Organics',
#  'Zydex',
#  'Directi',
#  'Hurix Systems',
#  'Aegis',
#  'UFO Moviez',
#  'Birlasoft',
#  'Impetus',
#  'Amity University',
#  "Moody's Analytics",
#  'Flipkart',
#  'Murugappa',
#  'ANSYS Software',
#  'Cipla',
#  'Info Edge',
#  'Sutherland',
#  'Religare Health Insurance',
#  'Bajaj Electricals',
#  'Dr Lal Pathlabs',
#  'BMC Software',
#  'Frankfinn',
#  'Applied Materials',
#  'Kotak Mahindra',
#  'DHFL Life Insurance',
#  'Tech Mahindra',
#  'Prokarma',
#  'Entrust Global',
#  'Data Intensity',
#  'Sterlite',
#  'Zensar',
#  'Torrent Pharma',
#  'Optum Global',
#  'Cadila',
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
from selenium import webdriver

# %%
url = 'https://www.naukri.com/step-up-list-of-companies-hiring-during-coronavirus-covid-19'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
print(html.prettify())
# Out:
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <base href="//www.naukri.com"/>
#   <meta content="notranslate" name="google"/>
#   <link href="https://static.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="https://img.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="https://logs.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="https://lg.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch preconnect"/>
#   <link href="https://www.googleadservices.com" rel="dns-prefetch preconnect"/>
#   <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch preconnect"/>
# ...

# %%
html = BeautifulSoup(driver.page_source, 'lxml')
entries = html.find_all('h2', class_='Company-name')
company_name = [e.get_text() for e in entries]
company_name
# Out:
# []

# %%
html.title.get_text()
# Out:
# 'Step Up - Companies Hiring During Coronavirus Covid-19 - A Naukri Initiative'

# %%
entries = html.find('h2', class_='Company-name')
print(entries)
# Out:
# None

# %%
html=BeautifulSoup(driver.page_source, 'lxml')
entries = html.find_all('h2', class_='company-name')
company_Name = [e.get_text() for e in entries]
company_Name
# Out:
# ['Tech Mahindra',
#  'MSN Laboratories',
#  'Tata Elxsi',
#  'DS Group',
#  'Wesley Clover',
#  'Muthoot Fincorp',
#  'Tata Steel',
#  'Veritas',
#  'Newt Global',
#  'Maintec',
#  'IDBI Life Insurance',
#  'Canara HSBC OBC Life Insurance',
#  'Amazon',
#  'Prime Focus',
#  'Tata Steel',
#  'Dell',
#  'HDFC Bank',
#  'HSBC EDP',
#  'O&G Skills',
#  'Atria',
#  'Meyer Organics',
#  'Zydex',
#  'Directi',
#  'Hurix Systems',
#  'Aegis',
#  'UFO Moviez',
#  'Birlasoft',
#  'Impetus']

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver

# %%
url = 'https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/dp/B01LZKSVRB/ref=br_msw_pdt-2/262-6341757-9816512?_encoding=UTF8&smid=A14CZOWI0VEHLG&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_s=&pf_rd_r=X7EK8ASDVFX38YZ1BWP9&pf_rd_t=36701&pf_rd_p=5c669f94-aee5-4b22-81f8-1d301ca2c6a3&pf_rd_i=desktop'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
product_name = html.find('div', class_='p13n-sc-truncate-desktop-type2 p13n-sc-truncated').get_text()
print(product_name)
# Out:
# New Apple iPhone 11 (64GB) - Black

# %%
entries = html.find_all('div', class_='p13n-sc-truncate-desktop-type2 p13n-sc-truncated')
product_name = [e.get_text() for e in entries]
product_name
# Out:
# ['New Apple iPhone 11 (64GB) - Black',
#  'Apple iPhone 11 Pro Max (512GB) - Space Grey',
#  'Samsung Galaxy M51 (Electric Blue, 6GB RAM, 128GB Storage)',
#  'Apple iPhone Xs (512GB) - Space Grey',
#  'New Apple iPhone 12 Mini (64GB) - Green',
#  'OpenTech® Tempered Glass Screen Protector for iPhone 6 / 6s / 7/8 with Installation kit (Full…',
#  'Egotude Soft Silicone Simple Slim Ultra Thin Back Cover Case for iPhone 7 (Black)',
#  'Jkobi Silicone Back Cover for Apple iPhone 7 | iPhone 8 - Transparent',
#  'Egotude India Shock Proof Hard Back Hybrid Cover Case for Apple iPhone 7 & iPhone 8…',
#  'OpenTech Tempered Glass Screen Protector Compatible for iPhone 7 with Edge to Edge…',
#  'Redmi Note 9 (Aqua Green, 4GB RAM, 64GB Storage) - 48MP Quad Camera & Full HD+…']

# %%
entries = html.find_all('a', class_='a-link-normal')
rating = [e.get_text() for e in entries]
rating
# Out:
# ['\n                Electronics\n            ',
#  '\n                Mobiles & Accessories\n            ',
#  '\n                Smartphones & Basic Mobiles\n            ',
#  '\n                 Smartphones\n             ',
#  'Share',
#  '',
#  '',
#  '',
#  '',
#  '\n\n\n\n\n\nSelect delivery location\n\n\n\n\n',
#  "\nWhat's this?\n",
#  'Apple AirPods with Charging Case',
#  'Apple AirPods with Wireless Charging Case',
#  '\nTerms & Conditions\n',
#  '\n',
#  'Apple AirPods with Charging Case',
#  'Apple AirPods with Wireless Charging Case',
#  '\n\n\n\n\nSecure transaction\n',
#  'Learn more',
#  '\n\n\n\n\n\nSelect delivery location\n\n\n\n\n',
#  '\n\n\n',
#  '\n\n\n',
#  'Visit the Apple Store',
#  '\n5,359 ratings\n',
#  '\n\n1000+ answered questions\n\n',
#  '\nClick to read EMI  FAQ ',
#  '\n        No-Contact Delivery\n    ',
#  '\n        \t\n7 Days Replacement\n    ',
#  '\n        Amazon Delivered\n    ',
#  '\n        1 Year Warranty\n    ',
# ...

# %%
entries = html.find_all('span', class_='p13n-sc-price')
price = [e.get_text() for e in entries]
price
# Out:
# ['₹\xa024,648.00',
#  '₹\xa023,990.00',
#  '₹\xa0259.00',
#  '₹\xa0499.00',
#  '₹\xa0399.00',
#  '₹\xa0499.00',
#  '₹\xa051,999.00',
#  '₹\xa01,21,900.00',
#  '₹\xa022,999.00',
#  '₹\xa097,900.00',
#  '₹\xa069,900.00',
#  '₹\xa0259.00',
#  '₹\xa0399.00',
#  '₹\xa0197.00',
#  '₹\xa0399.00',
#  '₹\xa0499.00',
#  '₹\xa011,999.00']

# %%
import pandas as pd

# %%
url = 'https://www.monsterindia.com/search/dashboard-jobs?searchId=c3b2518b-1667-405e-9980-5d441eff6a20'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')
entries = html.find_all('h3', class_='medium')
job_title = [e.get_text() for e in entries]
job_title
# Out:
# ['MIS Executive ',
#  'Power BI Developer',
#  'Power BI Consultant',
#  'MIS Executive ',
#  'Tableau Developer ',
#  'Product Analyst ',
#  'Tableau Developer ',
#  'Wanted Performance and Reporting Advisor for Qatar',
#  'Your payment will be sent to your account directly without any risk .',
#  'Power BI Developer',
#  'Wanted Performance and Reporting Specialist for Qatar ',
#  'L9 Manager Controllership - Client Accounting (J)',
#  'Openings for MIS Executive - Pune',
#  'Excellent job opening for Collection Business analyst with leading finance company at Pune',
#  'Software Design Engineer',
#  'Expert Engineer - Java',
#  'Software Design Engineer ',
#  'Software Design Engineer ',
#  'Applications are invited for the post of Senior Group Reporting Analyst in TopSource  ',
#  'Senior Group Reporting Analyst',
#  'Urgent : Wanted Senior Master Programmer for Qatar',
#  'Electronic Engineers',
#  'MIS Executive / Data Analyst',
#  'Electronic Engineers',
# ...

# %%
entries = html.find_all('span', class_='company-name')
company_name = [e.get_text() for e in entries]
company_name
# Out:
# ['Akash Bansal Group',
#  'Shorewise Consulting India Private Limited',
#  'Speegile Consulting',
#  'Advance Jobs Private Limited',
#  'Cloudray India Private Limited',
#  'Aditi Staffing India Private Limited',
#  'Techknomatic Services Private Limited',
#  '\n                                Company Name Confidential\n                            ',
#  '\n                                Company Name Confidential\n                            ',
#  'Techknomatic Services Private Limited',
#  '\n                                Company Name Confidential\n                            ',
#  '\n                                Company Name Confidential\n                            ',
#  'MD India Healthcare Networx Private Limited',
#  'Quess IT Staffing (Formerly known as Magna Infotech)',
#  'Afrin Sithara J (Proprietor Of Shahi India Co)',
#  'AasaanJobs Private Limited',
#  'Riju Karan (Proprietor Of Toyota Climax India)',
#  'Riju Karan (Proprietor Of Toyota Climax India)',
# ...

# %%
html=BeautifulSoup(driver.page_source, 'lxml')
entries = html.find_all('button', class_='line-btn btn-apply')
company_url = [e.get('href') for e in entries]
company_url
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df = pd.DataFrame({'Job_Title' : job_title, 'Company_Name' : company_name})
df
# Out:
#                                             Job_Title  \
# 0                                      MIS Executive
# 1                                  Power BI Developer
# 2                                 Power BI Consultant
# 3                                      MIS Executive
# 4                                  Tableau Developer
# 5                                    Product Analyst
# 6                                  Tableau Developer
# 7   Wanted Performance and Reporting Advisor for Q...
# 8   Your payment will be sent to your account dire...
# 9                                  Power BI Developer
# 10  Wanted Performance and Reporting Specialist fo...
# 11  L9 Manager Controllership - Client Accounting (J)
# 12                  Openings for MIS Executive - Pune
# 13  Excellent job opening for Collection Business ...
# 14                           Software Design Engineer
# 15                             Expert Engineer - Java
# ...

# %%
entries = html.find_all('button', class_='line-btn btn-apply')
link = [e.get_text() for e in entries]
link
# Out:
# ['APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY',
#  'APPLY']

# %%
entries = html.find_all('div', class_='card-apply-content')
link = [e.get_text() for e in entries]
link
# Out:
# ['MIS Executive  Akash Bansal Group  \n                                                Delhi\n                                                ,\n                                                Noida\n                                             \n                                                5-7 years\n                                              \n                                            240000 - 300000 INR\n                                         \n                            MIS Reports Advance Excel MIS Dashboard Excel reports Good verbal and written communication\n                         Skills :  \n                                                MIS Reports Advance Excel MIS Dashboard Excel reports Good verbal and written communication\n                                            ',
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
url = 'http://coreyms.com'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
entries = html.find_all('h2', class_='entry-title')
title = [e.get_text() for e in entries]
title
# Out:
# ['Python Tutorial: Zip Files – Creating and Extracting Zip Archives',
#  'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey',
#  'Python Multiprocessing Tutorial: Run Code in Parallel Using the Multiprocessing Module',
#  'Python Threading Tutorial: Run Code Concurrently Using the Threading Module',
#  'Update (2019-09-03)',
#  'Python Quick Tip: The Difference Between “==” and “is” (Equality vs Identity)',
#  'Python Tutorial: Calling External Commands Using the Subprocess Module',
#  'Visual Studio Code (Windows) – Setting up a Python Development Environment and Complete Overview',
#  'Visual Studio Code (Mac) – Setting up a Python Development Environment and Complete Overview',
#  'Clarifying the Issues with Mutable Default Arguments']

# %%
entries = html.find_all('div', class_='entry-content')
summary = [e.get_text() for e in entries]
summary
# Out:
# ['\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n',
#  '\nIn this Python Programming video, we will be learning how to download and analyze real-world data from the 2019 Stack Overflow Developer Survey. This is terrific practice for anyone getting into the data science field. We will learn different ways to analyze this data and also some best practices. Let’s get started…\n\n\n\n',
#  '\nIn this Python Programming video, we will be learning how to run code in parallel using the multiprocessing module. We will also look at how to process multiple high-resolution images at the same time using a ProcessPoolExecutor from the concurrent.futures module. Let’s get started…\n\n\n\n',
# ...

# %%
entries = html.find_all('a', class_='ytp-title-link yt-uix-sessionlink')
video_link = [e.get_text() for e in entries]
video_link
# Out:
# []

# %%
video = html.find_all('iframe', class_='youtube-player')
print(video)
# Out:
# [<iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/z0gguhEmWiY?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe>, <iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/_P7X8tMplsw?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe>, <iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/fKl2JW_qrso?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Title' : title, 'Summary' : summary})
df
# Out:
#                                                Title  \
# 0  Python Tutorial: Zip Files – Creating and Extr...
# 1  Python Data Science Tutorial: Analyzing the 20...
# 2  Python Multiprocessing Tutorial: Run Code in P...
# 3  Python Threading Tutorial: Run Code Concurrent...
# 4                                Update (2019-09-03)
# 5  Python Quick Tip: The Difference Between “==” ...
# 6  Python Tutorial: Calling External Commands Usi...
# 7  Visual Studio Code (Windows) – Setting up a Py...
# 8  Visual Studio Code (Mac) – Setting up a Python...
# 9  Clarifying the Issues with Mutable Default Arg...
#
#                                              Summary
# 0  \nIn this video, we will be learning how to cr...
# 1  \nIn this Python Programming video, we will be...
# 2  \nIn this Python Programming video, we will be...
# 3  \nIn this Python Programming video, we will be...
# 4  \nHey everyone. I wanted to give you an update...
# 5  \nIn this Python Programming Tutorial, we will...
# ...

# %%
df.loc[0,:]
# Out:
# Title      Python Tutorial: Zip Files – Creating and Extr...
# Summary    \nIn this video, we will be learning how to cr...
# Name: 0, dtype: object

# %%
url = 'https://covid19.who.int/table'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
entries = html.find_all('div', class_='sc-AxjAm sc-fzoMdx cTipgc')
countries_name = [ e.get_text() for e in entries]
countries_name
# Out:
# ['United States of America',
#  'Community transmission',
#  'India',
#  'Clusters of cases',
#  'Brazil',
#  'Community transmission',
#  'Russian Federation',
#  'Clusters of cases',
#  'France',
#  'Community transmission',
#  'The United Kingdom',
#  'Community transmission',
#  'Italy',
#  'Clusters of cases',
#  'Spain',
#  'Community transmission',
#  'Germany',
#  'Clusters of cases',
#  'Colombia',
#  'Community transmission',
#  'Argentina',
#  'Community transmission',
#  'Mexico',
#  'Community transmission',
#  'Turkey',
#  'Community transmission',
#  'Poland',
#  'Community transmission',
#  'Iran (Islamic Republic of)',
#  'Community transmission',
#  'Ukraine',
#  'Community transmission',
#  'South Africa',
#  'Community transmission',
#  'Peru',
#  'Community transmission',
#  'Netherlands',
#  'Community transmission',
#  'Indonesia',
#  'Community transmission']

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://coreyms.com'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
title = html.find('h2', class_='entry-title').get_text()
title = print(title)
title
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives

# %%
summary = html.find('div', class_='entry-content').get_text()
summary = print(summary)
summary
# Out:
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…

# %%
link = html.find('iframe', class_='youtube-player')['src']
link = print(link)
link
# Out:
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent

# %%
#for article in soup.find_all('article'):
#    title = html.find('h2', class_='entry-title').get_text()
#    print(title)
    
    
#    summary = html.find('div', class_='entry-content').get_text()
#    print(summary)
    
    
#    try:
#    link = html.find('iframe', class_='youtube-player')['src']
        
#    except Exception as e:
       
#    print(link)

# %%
#for article in soup.find_all('article'):
#    title = html.find('h2', class_='entry-title').get_text()
#    print(title)
#    summary = html.find('div', class_='entry-content').get_text()
#    print(summary)
#    link = html.find('iframe', class_='youtube-player')['src']
#    print(link)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://coreyms.com'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
items = html.find_all('article')
#print(items)
print(items[0])
# Out:
# <article class="post-1670 post type-post status-publish format-standard has-post-thumbnail category-development category-python tag-gzip tag-shutil tag-zip tag-zipfile entry" itemscope="" itemtype="https://schema.org/CreativeWork"><header class="entry-header"><h2 class="entry-title" itemprop="headline"><a class="entry-title-link" href="https://coreyms.com/development/python/python-tutorial-zip-files-creating-and-extracting-zip-archives" rel="bookmark">Python Tutorial: Zip Files – Creating and Extracting Zip Archives</a></h2>
# ...

# %%
print(items[0].find('h2', class_='entry-title').get_text())
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives

# %%
print(items[0].find('div', class_='entry-content').get_text())
# Out:
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…

# %%
print(items[0].find('iframe', class_='youtube-player')['src'])
# Out:
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent

# %%
heading = [item.find('h2', class_='entry-title').get_text() for item in items]
heading
# Out:
# ['Python Tutorial: Zip Files – Creating and Extracting Zip Archives',
#  'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey',
#  'Python Multiprocessing Tutorial: Run Code in Parallel Using the Multiprocessing Module',
#  'Python Threading Tutorial: Run Code Concurrently Using the Threading Module',
#  'Update (2019-09-03)',
#  'Python Quick Tip: The Difference Between “==” and “is” (Equality vs Identity)',
#  'Python Tutorial: Calling External Commands Using the Subprocess Module',
#  'Visual Studio Code (Windows) – Setting up a Python Development Environment and Complete Overview',
#  'Visual Studio Code (Mac) – Setting up a Python Development Environment and Complete Overview',
#  'Clarifying the Issues with Mutable Default Arguments']

# %%
Description = [item.find('div', class_='entry-content').get_text() for item in items]
Description
# Out:
# ['\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n',
#  '\nIn this Python Programming video, we will be learning how to download and analyze real-world data from the 2019 Stack Overflow Developer Survey. This is terrific practice for anyone getting into the data science field. We will learn different ways to analyze this data and also some best practices. Let’s get started…\n\n\n\n',
#  '\nIn this Python Programming video, we will be learning how to run code in parallel using the multiprocessing module. We will also look at how to process multiple high-resolution images at the same time using a ProcessPoolExecutor from the concurrent.futures module. Let’s get started…\n\n\n\n',
# ...

# %%
video_link = [items[0].find('iframe', class_='youtube-player')['src'] for item in items]
video_link
# Out:
# ['https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
#  'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
#  'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
#  'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
#  'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
#  'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent',
# ...

# %%
data = pd.DataFrame({'Heading': heading, 'Description': Description, 'Video_Link':video_link})
data
# Out:
#                                              Heading  \
# 0  Python Tutorial: Zip Files – Creating and Extr...
# 1  Python Data Science Tutorial: Analyzing the 20...
# 2  Python Multiprocessing Tutorial: Run Code in P...
# 3  Python Threading Tutorial: Run Code Concurrent...
# 4                                Update (2019-09-03)
# 5  Python Quick Tip: The Difference Between “==” ...
# 6  Python Tutorial: Calling External Commands Usi...
# 7  Visual Studio Code (Windows) – Setting up a Py...
# 8  Visual Studio Code (Mac) – Setting up a Python...
# 9  Clarifying the Issues with Mutable Default Arg...
#
#                                          Description  \
# 0  \nIn this video, we will be learning how to cr...
# 1  \nIn this Python Programming video, we will be...
# 2  \nIn this Python Programming video, we will be...
# 3  \nIn this Python Programming video, we will be...
# 4  \nHey everyone. I wanted to give you an update...
# 5  \nIn this Python Programming Tutorial, we will...
# ...

# %%
data.to_excel('Corey.xlsx')

# %%
items = html.find_all('article')
heading = [item.find('h2', class_='entry-title').get_text() for item in items]
Description = [item.find('div', class_='entry-content').get_text() for item in items]
video_link = [items[0].find('iframe', class_='youtube-player')['src'] for item in items]

# %%
video_link = [item.find('iframe', class_='youtube-player') for item in items]
video_link
# Out:
# [<iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/z0gguhEmWiY?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe>,
#  <iframe allowfullscreen="true" class="youtube-player" height="360" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation" src="https://www.youtube.com/embed/_P7X8tMplsw?version=3&amp;rel=1&amp;showsearch=0&amp;showinfo=1&amp;iv_load_policy=1&amp;fs=1&amp;hl=en-US&amp;autohide=2&amp;wmode=transparent" style="border:0;" width="640"></iframe>,
# ...

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
url = 'https://www.naukri.com/step-up-list-of-companies-hiring-during-coronavirus-covid-19'
url = requests.get(url)

# %%
html = BeautifulSoup(url.text, 'lxml')

# %%
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <base href="//www.naukri.com"/>
#   <meta content="notranslate" name="google"/>
#   <link href="https://static.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="https://img.naukimg.com" rel="dns-prefetch preconnect"/>
#   <link href="https://logs.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="https://lg.naukri.com" rel="dns-prefetch preconnect"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch preconnect"/>
#   <link href="https://www.googleadservices.com" rel="dns-prefetch preconnect"/>
#   <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch preconnect"/>
# ...

# %%
company_name = html.find('h2', class_='company-name')
print(company_name)
# Out:
# None

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
url = 'https://www.naukri.com/step-up-list-of-companies-hiring-during-coronavirus-covid-19'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
company_name = html.find_all('h2', class_='company-name')
company_name = [c.get_text() for c in company_name]
company_name
# Out:
# ['eInfochips',
#  'Lovely Professional University',
#  'HDFC Life Insurance',
#  'Muthoot Fincorp',
#  'Markit',
#  'Applied Materials',
#  'Amity University',
#  'Cyient',
#  'Bajaj Electricals',
#  'Allstate Solutions',
#  'SBI',
#  'Capita',
#  'Unisys',
#  'Ingram Micro',
#  'Standard Chartered',
#  'Genpact',
#  'Saint-Gobain',
#  'Tech Mahindra',
#  'People Interactive',
#  'Alkem Laboratories',
#  'Mindtree',
#  'Brillio',
#  'Apeejay Education',
#  'QuickHeal',
#  'Proptiger',
#  'Murugappa',
#  'Sykes',
#  'Amicorp Management']

# %%
opening = html.find_all('span', class_='company-jobs')
opening = [c.get_text() for c in opening]
opening
# Out:
# ['12 Openings',
#  '1 Opening',
#  '8 Openings',
#  '6 Openings',
#  '4 Openings',
#  '21 Openings',
#  '19 Openings',
#  '5 Openings',
#  '3 Openings',
#  '10 Openings',
#  '1 Opening',
#  '11 Openings',
#  '1 Opening',
#  '5 Openings',
#  '7 Openings',
#  '96 Openings',
#  '7 Openings',
#  '50 Openings',
#  '9 Openings',
#  '2 Openings',
#  '39 Openings',
#  '4 Openings',
#  '19 Openings',
#  '4 Openings',
#  '18 Openings',
#  '24 Openings',
#  '3 Openings',
#  '1 Opening']

# %%
link = html.find_all('a', class_='overlay')
link = [c.get('href') for c in link]
link
# Out:
# ['https://www.naukri.com/einfochips-pvt-ltd-jobs-careers-835251?jobAge=15',
#  'https://www.naukri.com/lovely-international-trust-jobs-careers-278939?jobAge=15',
#  'https://www.naukri.com/hdfc-life-insurance-company-limited-jobs-careers-5296094?jobAge=15',
#  'https://www.naukri.com/muthoot-fincorp-ltd-jobs-careers-97505?jobAge=15',
#  'https://www.naukri.com/markit-india-services-jobs-careers-627609?jobAge=15',
#  'https://www.naukri.com/applied-materials-jobs-careers-2088272?jobAge=15',
#  'https://www.naukri.com/amity-university-jobs-careers-414239?jobAge=15',
#  'https://www.naukri.com/cyient-limited-jobs-careers-574?jobAge=15',
#  'https://www.naukri.com/bajaj-electricals-limited-jobs-careers-22840?jobAge=15',
#  'https://www.naukri.com/allstate-solutions-private-limited-jobs-careers-944446?jobAge=15',
#  'https://www.naukri.com/sbi-payment-services-jobs-careers-994028?jobAge=15',
#  'https://www.naukri.com/capita-india-pvt-ltd-jobs-careers-143636?jobAge=15',
# ...

# %%
company_type = html.find_all('span', class_='company-type')
company_type = [c.get_text() for c in company_type]
company_type
# Out:
# ['MNC',
#  'Corporate',
#  'Corporate',
#  'Corporate',
#  'MNC',
#  'MNC',
#  'Corporate',
#  'MNC',
#  'Corporate',
#  'Corporate',
#  'Corporate',
#  'MNC',
#  'MNC',
#  'MNC',
#  'MNC',
#  'MNC',
#  'MNC',
#  'MNC',
#  'Corporate',
#  'MNC',
#  'MNC',
#  'MNC',
#  'Corporate',
#  'Corporate',
#  'Unicorn',
#  'Corporate',
#  'MNC',
#  'MNC']

# %%
url = 'http://www.maati.net/Home/ContactUs'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
#Name
driver.find_element_by_id('name').send_keys('Arun')

#contact No
driver.find_element_by_id('Contact').send_keys(8920401748)

#Email ID
driver.find_element_by_id('cainput_email').send_keys('Arunsharma98@gmail.com')

#Subject
driver.find_element_by_id('cainput_subject').send_keys('Tableau')

#message
driver.find_element_by_id('cainput_message').send_keys('Just wanted to learn tableu. what would be the fee stucture for the same')

# %%
button = driver.find_element_by_id('cainput_submit')
button.click()

# %%
url = 'https://www.amazon.com'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
product_name = html.find_all('h2', class_='a-size-mini a-color-base apb-line-clamp-3 a-text-normal')
product_name = [p.get_text() for p in product_name]
product_name
# Out:
# ['\n    Nintendo Switch with Neon Blue and Neon Red Joy‑Con - HAC-001(-01)\n',
#  '\n    Oculus Quest 2 — Advanced All-In-One Virtual Reality Headset — 256 GB\n',
#  '\n    Ring Fit Adventure - Nintendo Switch\n',
#  '\n    DualSense Wireless Controller\n',
#  '\n    Nintendo Switch Pro Controller\n',
#  '\n    PlayStation 4 Slim 1TB Console\n',
#  '\n    Nintendo Switch with Gray Joy‑Con -\xa0HAC-001(-01)\n',
#  '\n    Just Dance 2021 - Nintendo Switch Standard Edition\n',
#  '\n    Oculus Rift S PC-Powered VR Gaming Headset\n',
#  '\n    Xbox Core Controller - Carbon Black\n',
#  '\n    Super Mario 3D All-Stars - Nintendo Switch\n',
#  '\n    SanDisk 128GB microSDXC UHS-I-Memory-Card for Nintendo-Switch - SDSQXAO-128G-GNCZN, Red\n']

# %%
company_name = html.find_all('span', class_='a-size-base a-color-secondary a-text-normal')
company_name = [p.get_text() for p in company_name]
company_name
# Out:
# ['by Nintendo',
#  'by Oculus',
#  'by Nintendo',
#  'by PlayStation',
#  'by Nintendo',
#  'by PlayStation',
#  'by Nintendo',
#  'by Ubisoft',
#  'by Oculus',
#  'by Microsoft',
#  'by Nintendo',
#  'by SanDisk']

# %%
rating = html.find_all('i', class_='a-icon a-icon-star-small a-star-small-5')
rating = [p.get_text() for p in rating]
rating
# Out:
# ['', '', '', '', '', '', '', '', '', '']

# %%
link = html.find_all('a', class_='a-link-normal')
link = [p.get('href') for p in link]
link
# Out:
# ['/s/ref=s9_acss_bw_cts_AEVNVIDE_T1_w?fst=as%3Aoff&rh=i%3Aspecialty-aps%2Cn%3A%2116225016011%2Cp_89%3ANintendo&bbn=16225016011&ie=UTF8&qid=1510596876&rnid=2528832011&pf_rd_m=ATVPDKIKX0DER&pf_rd_s=merchandised-search-3&pf_rd_r=AGY205SDBKH2P6ENJ6GY&pf_rd_t=101&pf_rd_p=03b28c2c-71e9-4947-aa06-f8b5dc8bf880&pf_rd_i=16225016011',
#  '/s/ref=s9_acss_bw_cts_AEVNVIDE_T2_w?fst=as%3Aoff&rh=i%3Aspecialty-aps%2Cn%3A%2116225016011%2Cp_89%3APlaystation&bbn=16225016011&ie=UTF8&qid=1510597020&rnid=2528832011&pf_rd_m=ATVPDKIKX0DER&pf_rd_s=merchandised-search-3&pf_rd_r=AGY205SDBKH2P6ENJ6GY&pf_rd_t=101&pf_rd_p=03b28c2c-71e9-4947-aa06-f8b5dc8bf880&pf_rd_i=16225016011',
# ...

# %%
data = pd.DataFrame({'product_name': product_name, 'company_name':company_name})
data
# Out:
#                                          product_name    company_name
# 0   \n    Nintendo Switch with Neon Blue and Neon ...     by Nintendo
# 1   \n    Oculus Quest 2 — Advanced All-In-One Vir...       by Oculus
# 2        \n    Ring Fit Adventure - Nintendo Switch\n     by Nintendo
# 3               \n    DualSense Wireless Controller\n  by PlayStation
# 4              \n    Nintendo Switch Pro Controller\n     by Nintendo
# 5              \n    PlayStation 4 Slim 1TB Console\n  by PlayStation
# 6   \n    Nintendo Switch with Gray Joy‑Con - HAC-...     by Nintendo
# 7   \n    Just Dance 2021 - Nintendo Switch Standa...      by Ubisoft
# 8   \n    Oculus Rift S PC-Powered VR Gaming Heads...       by Oculus
# 9         \n    Xbox Core Controller - Carbon Black\n    by Microsoft
# 10  \n    Super Mario 3D All-Stars - Nintendo Swit...     by Nintendo
# 11  \n    SanDisk 128GB microSDXC UHS-I-Memory-Car...      by SanDisk

# %%
data1 = pd.DataFrame({'link':link})
data1
# Out:
#                                                  link
# 0   /s/ref=s9_acss_bw_cts_AEVNVIDE_T1_w?fst=as%3Ao...
# 1   /s/ref=s9_acss_bw_cts_AEVNVIDE_T2_w?fst=as%3Ao...
# 2   /s/ref=s9_acss_bw_cts_AEVNVIDE_T3_w?fst=as%3Ao...
# 3   /s/ref=s9_acss_bw_cts_AEVNVIDE_T4_w?fst=as%3Ao...
# 4   /Nintendo-Switch-Neon-Blue-Joy%E2%80%91/dp/B07...
# ..                                                ...
# 84  /product-reviews//B08FC6C75Y/ref=acr_search_hi...
# 85  /product-reviews//B08FC6C75Y/ref=acr_search_hi...
# 86  /product-reviews//B08FC6C75Y/ref=acr_search_hi...
# 87  /product-reviews//B08FC6C75Y/ref=acr_search_hi...
# 88  /product-reviews//B08FC6C75Y/ref=acr_search_hi...
#
# [89 rows x 1 columns]

# %%
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os

# %%
pdf_file= r'E:\notes\noorain_python\py_pdf(26-Jul-20)\scan_pdf.pdf'

# %%
pages=convert_from_path(pdf_file, poppler_path=r'E:\notes\noorain_python\py_pdf(26-Jul-20)\popplar\poppler-0.68.0\bin')

# %%
fileName='page_1'
for page in pages:
    page.save(fileName,'JPEG')

# %%
outputFile='ouput_1.txt'

# %%
f=open(outputFile,"a")

# %%
#'E:\notes\noorain_python\py_pdf(26-Jul-20)\tesseract-ocr-w64-setup-v5.0.0-alpha.20200328.exe

pytesseract.pytesseract.tesseract_cmd='E:\notes\noorain_python\py_pdf(26-Jul-20)\tesseract-ocr-w64-setup-v5.0.0-alpha.20200328.exe'

# %%
text=str(pytesseract.image_to_string(Image.open(fileName)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254     try:
# --> 255         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256     except OSError as e:
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://coreyms.com'
path_to_driver = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path_to_driver)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
try:
    for article in html.find_all('article'):
        title = html.find('h2', class_='entry-title').get_text()
        print(title)
        About = html.find('div', class_='entry-content').get_text()
        print(About)
        link = html.find('iframe', class_='youtube-player')['src']
        print(link)
except:
    link = None
    
    Print()
# Out:
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives
#
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…
#
#
# https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives
#
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…
#
#
# ...

# %%
url = 'https://www.naukri.com/step-up-list-of-companies-hiring-during-coronavirus-covid-19'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
try:
    for card in html.find_all('div', class_='company-card'):
        Company_name = html.find('h2', class_='company-name').get_text()
        print(Company_name)
        Openings = html.find('span', class_='company-jobs').get_text()
        print(Openings)
        Type = html.find('span', class_='company-type').get_text()
        print(Type)
        link = html.find('a', class_='overlay').get('href')
        print(link)
except:
    link = None
    
    Print()
# Out:
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
# 2 Openings
# MNC
# ...

# %%
for card in html.find_all('div', class_='company-card'):
        Company_name = html.find('h2', class_='company-name').get_text()
        print(Company_name)
        print()
        Openings = html.find('span', class_='company-jobs').get_text()
        print(Openings)
        print()
        Type = html.find('span', class_='company-type').get_text()
        print(Type)
        print()
        link = html.find('a', class_='overlay').get('href')
        print(link)
# Out:
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# Alten Calsoft Labs
#
# 2 Openings
#
# MNC
#
# https://www.naukri.com/alten-calsoft-labs-india-private-limited-jobs-careers-3212?jobAge=15
# ...

# %%
url = 'https://facebook.com'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
driver.find_element_by_id('email').send_keys('himanshupathak48@gmail.com')
driver.find_element_by_id('pass').send_keys('anshu123')
button = driver.find_element_by_id('u_0_b')
button.click()

# %%
url = 'https://instagram.com'
path = 'E://notes//noorain_python//python Class(30-Aug)//chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
html = BeautifulSoup(driver.page_source, 'lxml')

# %%
driver.find_element_by_name('username').send_keys('anshu8802496912')
driver.find_element_by_name('password').send_keys('anshu8802496912')
button = driver.find_element_by_tag_name('div')
button.click()
